# %%
import pandas as pd

# %% [markdown]
# Data can be found here: https://covid19.who.int/data

# %% [markdown]
# # Daily cases and deaths by date reported to WHO

# %%
url = 'https://covid19.who.int/WHO-COVID-19-global-data.csv'
daily_case_deaths = pd.read_csv(url,index_col=0)

# %%
daily_case_deaths
# Out:
#               Country_code      Country WHO_region  New_cases  \
# Date_reported
# 2020-01-03              AF  Afghanistan       EMRO          0
# 2020-01-04              AF  Afghanistan       EMRO          0
# 2020-01-05              AF  Afghanistan       EMRO          0
# 2020-01-06              AF  Afghanistan       EMRO          0
# 2020-01-07              AF  Afghanistan       EMRO          0
# ...                    ...          ...        ...        ...
# 2022-10-03              ZW     Zimbabwe       AFRO          0
# 2022-10-04              ZW     Zimbabwe       AFRO          0
# 2022-10-05              ZW     Zimbabwe       AFRO          0
# 2022-10-06              ZW     Zimbabwe       AFRO          0
# 2022-10-07              ZW     Zimbabwe       AFRO          0
#
#                Cumulative_cases  New_deaths  Cumulative_deaths
# Date_reported
# 2020-01-03                    0           0                  0
# 2020-01-04                    0           0                  0
# ...

# %%
daily_case_deaths.loc[daily_case_deaths['Country'] == 'Saba'] # need to combine  Bonaire, Saint Eustatius and Saba at a later stage
# Out:
#               Country_code Country WHO_region  New_cases  Cumulative_cases  \
# Date_reported
# 2020-01-03              XC    Saba       AMRO          0                 0
# 2020-01-04              XC    Saba       AMRO          0                 0
# 2020-01-05              XC    Saba       AMRO          0                 0
# 2020-01-06              XC    Saba       AMRO          0                 0
# 2020-01-07              XC    Saba       AMRO          0                 0
# ...                    ...     ...        ...        ...               ...
# 2022-10-03              XC    Saba       AMRO          0               730
# 2022-10-04              XC    Saba       AMRO          0               730
# 2022-10-05              XC    Saba       AMRO          0               730
# 2022-10-06              XC    Saba       AMRO          0               730
# 2022-10-07              XC    Saba       AMRO          0               730
#
#                New_deaths  Cumulative_deaths
# ...

# %%
'''
display_country = 'Zimbabwe'
daily_case_deaths[daily_case_deaths['Country']== display_country]
'''
# Out:
# "\ndisplay_country = 'Zimbabwe'\ndaily_case_deaths[daily_case_deaths['Country']== display_country]\n"

# %%
daily_case_deaths.to_csv(r'./WHO-COVID-19-global-data.csv', encoding='utf-8', header='true')

# %% [markdown]
# # Latest reported counts of cases and deaths

# %%
url = 'https://covid19.who.int/WHO-COVID-19-global-table-data.csv'
latest_count = pd.read_csv(url,index_col=0)

# %%
latest_count
# Out:
#                                                   Name  WHO Region  \
# Global                                             NaN   617597680
# United States of America                      Americas    95260865
# India                                  South-East Asia    44606460
# Brazil                                        Americas    34699017
# France                                          Europe    34665044
# ...                                                ...         ...
# Tuvalu                                 Western Pacific          20
# Pitcairn Islands                       Western Pacific           4
# Democratic People's Republic of Korea  South-East Asia           0
# Tokelau                                Western Pacific           0
# Turkmenistan                                    Europe           0
#
#                                        Cases - cumulative total  \
# Global                                              7923.465035
# ...

# %%
latest_count.to_csv(r'./WHO-COVID-19-global-table-data.csv', encoding='utf-8', header='true')

# %% [markdown]
# # Vaccination Data

# %%
url = 'https://covid19.who.int/who-data/vaccination-data.csv'
vac_data = pd.read_csv(url,index_col=0)

# %%
vac_data
# Out:
#                   ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# COUNTRY
# Afghanistan        AFG       EMRO   REPORTING   2022-10-04
# Albania            ALB       EURO   REPORTING   2022-09-18
# Algeria            DZA       AFRO   REPORTING   2022-09-04
# American Samoa     ASM       WPRO   REPORTING   2022-08-23
# Andorra            AND       EURO   REPORTING   2022-09-11
# ...                ...        ...         ...          ...
# Viet Nam           VNM       WPRO   REPORTING   2022-09-22
# Wallis and Futuna  WLF       WPRO   REPORTING   2022-07-26
# Yemen              YEM       EMRO   REPORTING   2022-09-28
# Zambia             ZMB       AFRO   REPORTING   2022-09-25
# Zimbabwe           ZWE       AFRO   REPORTING   2022-10-02
#
#                    TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# COUNTRY
# Afghanistan                11923733.0                     10961643.0
# Albania                     2974247.0                      1336938.0
# ...

# %%
vac_data.to_csv(r'./vaccination-data.csv', encoding='utf-8', header='true')

# %% [markdown]
# # Vaccination metadata

# %%
url = 'https://covid19.who.int/who-data/vaccination-metadata.csv'
vac_metadata= pd.read_csv(url,index_col=0)

# %%
vac_metadata
# Out:
#                      VACCINE_NAME     PRODUCT_NAME     COMPANY_NAME  \
# ISO3
# SHN         AstraZeneca - AZD1222          AZD1222      AstraZeneca
# GRL           Moderna - mRNA-1273        mRNA-1273          Moderna
# FRO           Moderna - mRNA-1273        mRNA-1273          Moderna
# FRO   Pfizer BioNTech - Comirnaty        Comirnaty  Pfizer BioNTech
# BIH         AstraZeneca - AZD1222          AZD1222      AstraZeneca
# ...                           ...              ...              ...
# TKM               Unknown Vaccine  Unknown Vaccine              NaN
# UZB               Unknown Vaccine  Unknown Vaccine              NaN
# MCO             Novavax - Covavax          Covavax              NaN
# THA                 SII - Covovax          Covovax              NaN
# IND                 SII - Covovax          Covovax              NaN
#
#      AUTHORIZATION_DATE  START_DATE  END_DATE  COMMENT DATA_SOURCE
# ISO3
# SHN                 NaN         NaN       NaN      NaN        OWID
# ...

# %%
vac_metadata.to_csv(r'./vaccination-metadata.csv', encoding='utf-8', header='true')
